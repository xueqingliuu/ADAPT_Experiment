# %%
# STE for ``vani_env`` + ``OnlineEnv`` (DQN vs zero policy), mirroring STE6 archive.
# Full pipeline: ``ste_vanilla.py`` (CLI) or import the helpers below.

import numpy as np
from pathlib import Path

from ste_vanilla import aggregate_ste, eval_ste_job, train_ste_job

# Example: ``jobid`` indexes a line in ``env_para_vanilla/user_ids.txt`` (0 = first user).
jobid = 0

# 1) Train DQN on offline data (requires ``pip install d3rlpy``).
train_ste_job(jobid, exp="1", n_train_episodes=2000, n_steps=50_000, nweek=36)

# 2) After models exist under ``d3rlpy_logs/ste_exp_1/``, evaluate zero vs greedy.
eval_ste_job(jobid, exp="1", n_test=200, nweek=36)

# 3) Pooled STE from ``results_ste/exp1/res1_{userid}.txt`` (two columns: zero-policy vs DQN total CAE).
ste = aggregate_ste("1", burn_in_rows=0)
print(ste)
# Out:
# 2026-04-13 09:46.00 [info     ] Signatures have been automatically determined. action_signature=Signature(dtype=[dtype('int64')], shape=[(1,)]) observation_signature=Signature(dtype=[dtype('float64')], shape=[(69,)]) reward_signature=Signature(dtype=[dtype('float64')], shape=[(1,)])
# 2026-04-13 09:46.00 [info     ] dataset info                   dataset_info=DatasetInfo(observation_signature=Signature(dtype=[dtype('float64')], shape=[(69,)]), action_signature=Signature(dtype=[dtype('int64')], shape=[(1,)]), reward_signature=Signature(dtype=[dtype('float64')], shape=[(1,)]), action_space=<ActionSpace.DISCRETE: 2>, action_size=2)
# 2026-04-13 09:46.00 [debug    ] Building models...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 13
#      10 jobid = 0
#      12 # 1) Train DQN on offline data (requires ``pip install d3rlpy``).
# ...
